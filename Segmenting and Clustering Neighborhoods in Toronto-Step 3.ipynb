# %%
import pandas as pd
import numpy as np

# %%
#Getting data; The dataframe with three columns: PostalCode, Borough, and Neighborhood
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
wiki_data=pd.DataFrame(df[0])
wiki_data
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %%
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

df1= wiki_data[wiki_data['Borough'] != 'Not assigned']
df1.head(30)
# Out:
#    Postal Code           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# 8          M9A         Etobicoke
# 9          M1B       Scarborough
# 11         M3B        North York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M6B        North York
# 17         M9B         Etobicoke
# 18         M1C       Scarborough
# 20         M3C        North York
# 21         M4C         East York
# 22         M5C  Downtown Toronto
# 23         M6C              York
# 26         M9C         Etobicoke
# 27         M1E       Scarborough
# 30         M4E      East Toronto
# 31         M5E  Downtown Toronto
# 32         M6E              York
# 36         M1G       Scarborough
# 39         M4G         East York
# 40         M5G  Downtown Toronto
# 41         M6G  Downtown Toronto
# 45         M1H       Scarborough
# ...

# %%
#In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

df1.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Step 2- Reading Geographical Co-ordinates

# %%
geo_location= pd.read_csv('http://cocl.us/Geospatial_data')
geo_location
df1['Latitude']= geo_location['Latitude']
df1['Longitude']=geo_location['Longitude']
df1.head(30)
# Out:
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#    Postal Code           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# ...

# %%
df1.dropna()
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 95          M6N              York
# 98          M9N              York
# 99          M1P       Scarborough
# 100         M2P        North York
# 102         M4P   Central Toronto
#
#                                           Neighborhood   Latitude  Longitude
# 2                                            Parkwoods  43.763573 -79.188711
# 3                                     Victoria Village  43.770992 -79.216917
# 4                            Regent Park, Harbourfront  43.773136 -79.239476
# 5                     Lawrence Manor, Lawrence Heights  43.744734 -79.239476
# 6          Queen's Park, Ontario Provincial Government  43.727929 -79.262029
# ..                                                 ...        ...        ...
# ...

# %% [markdown]
# ## Step 3- Exploring and Clustering Neighborhoods

# %%
toronto_df=df1[df1['Borough'].str.contains('Toronto')].dropna()
toronto_df.head(39)
# Out:
#     Postal Code           Borough  \
# 4           M5A  Downtown Toronto
# 6           M7A  Downtown Toronto
# 13          M5B  Downtown Toronto
# 22          M5C  Downtown Toronto
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# 49          M5H  Downtown Toronto
# 50          M6H      West Toronto
# 58          M5J  Downtown Toronto
# 59          M6J      West Toronto
# 66          M4K      East Toronto
# 67          M5K  Downtown Toronto
# 68          M6K      West Toronto
# 75          M4L      East Toronto
# 76          M5L  Downtown Toronto
# 84          M4M      East Toronto
# 93          M4N   Central Toronto
# 94          M5N   Central Toronto
# 102         M4P   Central Toronto
#
#                                           Neighborhood   Latitude  Longitude
# 4                            Regent Park, Harbourfront  43.773136 -79.239476
# ...

# %%
toronto_df.shape
# Out:
# (21, 5)

# %%
#importing map library to plot map. # Toronto location

import folium

# %% [markdown]
# ### Used Toronto latitude and logitude to show map and iterated same on Toronto_df to plot all zip borough and Neighborhood as per latitude and longitude

# %%
latitude = 43.6532
longitude= -79.3832
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
map_toronto

for lat, lng, label in zip(toronto_df['Latitude'], toronto_df['Longitude'], toronto_df['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Define Foursquare Credentials and Version

# %%
CLIENT_ID = '5SXN5GB3QW2YKIDWFN50SMEIY2AGSLZ5A1SG1SILONJY42BZ' # Foursquare ID
CLIENT_SECRET = 'QCTOHNJVAAA1I0GWHCJ3VTS3NG4UELT0OY0GEW5YOAFGMZ5Y' # Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5SXN5GB3QW2YKIDWFN50SMEIY2AGSLZ5A1SG1SILONJY42BZ
# CLIENT_SECRET:QCTOHNJVAAA1I0GWHCJ3VTS3NG4UELT0OY0GEW5YOAFGMZ5Y

# %% [markdown]
# ## Getting data through Foresquare API using Function as done in Lab experiments

# %%
import requests
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_df['Neighborhood'],
                                   latitudes=toronto_df['Latitude'],
                                   longitudes=toronto_df['Longitude']
                                  )
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (508, 7)
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront              43.773136              -79.239476
# 1  Regent Park, Harbourfront              43.773136              -79.239476
# 2  Regent Park, Harbourfront              43.773136              -79.239476
# 3  Regent Park, Harbourfront              43.773136              -79.239476
# 4  Regent Park, Harbourfront              43.773136              -79.239476
#
#                           Venue  Venue Latitude  Venue Longitude  \
# 0           Federick Restaurant       43.774697       -79.241142
# 1      Drupati's Roti & Doubles       43.775222       -79.241678
# 2                   Thai One On       43.774468       -79.241268
# 3               TD Canada Trust       43.774830       -79.241251
# 4  Centennial Recreation Centre       43.774593       -79.236500
#
#          Venue Category
# 0      Hakka Restaurant
# 1  Caribbean Restaurant
# 2       Thai Restaurant
# ...

# %% [markdown]
# # Grouping Neighborhood

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                    Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            5
# Brockton, Parkdale Village, Exhibition Place                          14
# Central Bay Street                                                     3
# Christie                                                              42
# Commerce Court, Victoria Hotel                                        15
# Davisville North                                                       3
# Dufferin, Dovercourt Village                                           4
# Garden District, Ryerson                                              11
# Harbourfront East, Union Station, Toronto Islands                     96
# India Bazaar, The Beaches West                                        17
# Little Portugal, Trinity                                             100
# Queen's Park, Ontario Provincial Government                            5
# ...

# %% [markdown]
# ## Finding out unique categories

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 161 uniques categories.
